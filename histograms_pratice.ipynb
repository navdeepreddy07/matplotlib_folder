# %%
from matplotlib import pyplot as plt


marks=[40,67,60,40,66,55,50,75,20]
plt.hist(marks,bins=7)
plt.show()

# %%
marks = [35, 42, 48, 51, 55, 61, 65, 67, 72, 78, 82, 89, 91]
plt.hist(marks,bins=10)
plt.title("Distribution of Student Marks")
plt.xlabel("marks")
plt.ylabel("no of students")
plt.show()

# %%
marks = [35, 42, 48, 51, 55, 61, 65, 67, 72, 78, 82, 89, 91]
plt.hist(marks,bins=5)
plt.title("Distribution of Student Marks")
plt.xlabel("marks")
plt.ylabel("no of students")
plt.show()

# %%
30–50, 50–70, 70–90, 90–100marks = [35, 42, 48, 51, 55, 61, 65, 67, 72, 78, 82, 89, 91]
plt.hist(marks,bins=10)
plt.show()

# %%
marks = [35, 42, 48, 51, 55, 61, 65, 67, 72, 78, 82, 89, 91]
plt.hist(marks,bins=[30,50,70,90,100])
# Out:
# (array([3., 5., 4., 1.]),
#  array([ 30.,  50.,  70.,  90., 100.]),
#  <BarContainer object of 4 artists>)
